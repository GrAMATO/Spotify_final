# %% [markdown]
# # API spotify

# %%
#https://pypi.org/project/spotipy/
client_id = "3cb0361e67fc4ae8ac052aea630d70a3"
client_secret = "a13ee6894c0d496ebc7490f4d26e23e3"

# %% [markdown]
# - expliquer comment gérer une bdd en format excel
# - regrouper libellés

# %%
import requests
import json
import pandas as pd
import base64
import datetime
from urllib.parse import urlencode

# %% [markdown]
# # Définition du token d'accès

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"

    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret


    def get_client_credentials(self):

        #Returns a base64 encoded string

        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()

    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
        "Authorization": f"Basic {client_creds_b64}" 
        }

    def get_token_data(self):
        return {
        "grant_type": "client_credentials"
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299): 
            raise Exception("Could not authenticate client")
          #return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires 
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token

# %%
spoti = SpotifyAPI(client_id, client_secret)

# %%
access_token = 'BQCGgKq_ke61B21bjoWToT2ChhDvaMrVegmw_Iyfr5eMh-bG0G9Tiqf5KQ2iIF94alpgRulRQOvo1441a8zslSBG0RmA7YMaZHUDtPj8xwu5dalxhTwKVivHnonNr9kZb32onIeybfdmvXEGKVUIRHPaGSu10jIloI-R087CbLufk08-'
def get_playlists(access_token):    
    dict_playlists = {"names":[], "description":[], "url":[], "id":[], "image":[], "public":[]} 
    headers = {
      "Authorization": f"Bearer {access_token}"
    }
    url = 'https://api.spotify.com/v1/users/spotify/playlists'
    j = 0
    for i in range(0,1450,50):
        try:
            params = {'limit': 50, 'offset': i}
            r = requests.get(url, headers=headers, params=params) 
            if str(r) == '<Response [401]>' :
                print("access_token")
                return dict_playlists
            else:
                print("OK")
                response_dict = json.loads(r.text)
                for j in range(50):
                    try:
                        dict_playlists["names"].append(response_dict["items"][j]["name"])
                        dict_playlists["description"].append(response_dict["items"][j]["description"])
                        dict_playlists["url"].append(response_dict["items"][j]["external_urls"]["spotify"])
                        dict_playlists["id"].append(response_dict["items"][j]["id"])
                        try:
                            dict_playlists["image"].append(response_dict["items"][j]["images"][0]["url"])
                        except:
                            dict_playlists["image"].append("")
                        try:
                            dict_playlists["public"].append(response_dict["items"][j]["public"])
                        except:
                            dict_playlists["public"].append("")
                        j+=1
                    except:
                        break
        except:
            return dict_playlists
    return dict_playlists

# %%
dict_playlists_full = get_playlists(access_token)
# Out:
# access_token

# %%
data_playlists = pd.DataFrame.from_dict(dict_playlists_full)

# %%
data_playlists.to_csv("data_playlists.csv")

# %%
access_token = 'BQDWBGKzyy_p-hP8BZ8m08qSvZxEN1NmGPjKG7yBrQeKphQj35n3AwvEWSXpaUqMZqE95nlVHAAVqmcgHqH1rpHRIFY-GW7b_6udIY9jIjfkeHdjGgf3IuRiNfPwAv_nugg4qkYTe_Md4cBmyviTjFi0ZMbOn1l1e_9F66FXKXtu0zfa'
def get_playlists(access_token):    
    """Récupère les informations des playlists"""
    dict_playlists = {"names":[], "description":[], "url":[], "id":[], "image":[], "public":[]} 
    headers = {
      "Authorization": f"Bearer {access_token}"
    }
    j = 0
    for i in range(0,1450,50):
        try:
            params = {'limit': 50, 'offset': i}
            r = requests.get(url, headers=headers, params=params) 
            if str(r) == '<Response [401]>' :
                print("access_token")
                return dict_playlists
            else:
                print("OK")
                response_dict = json.loads(r.text)
                for k in data_playlists[id]:
                    endpoint = "https://api.spotify.com/v1/playlists/" + str(k) + "/tracks"
                    
                    
                for j in range(50):
                    try:
                        dict_playlists["names"].append(response_dict["items"][j]["name"])
                        dict_playlists["description"].append(response_dict["items"][j]["description"])
                        dict_playlists["url"].append(response_dict["items"][j]["external_urls"]["spotify"])
                        dict_playlists["id"].append(response_dict["items"][j]["id"])
                        try:
                            dict_playlists["image"].append(response_dict["items"][j]["images"][0]["url"])
                        except:
                            dict_playlists["image"].append("")
                        try:
                            dict_playlists["public"].append(response_dict["items"][j]["public"])
                        except:
                            dict_playlists["public"].append("")
                    except:
                        break
        except:
            return dict_playlists
    return dict_playlists

# %%
access_token = 'BQDWBGKzyy_p-hP8BZ8m08qSvZxEN1NmGPjKG7yBrQeKphQj35n3AwvEWSXpaUqMZqE95nlVHAAVqmcgHqH1rpHRIFY-GW7b_6udIY9jIjfkeHdjGgf3IuRiNfPwAv_nugg4qkYTe_Md4cBmyviTjFi0ZMbOn1l1e_9F66FXKXtu0zfa'
headers = {
  "Authorization": f"Bearer {access_token}"
}
endpoint = "https://api.spotify.com/v1/playlists/" + "37i9dQZF1DXcBWIGoYBM5M" + "/tracks"
params = {'market:'FR', limit': 50, 'offset': 0}
r = requests.get(endpoint, headers=headers, params=params)

# %%
tracks_dict = json.loads(r.text)

# %%
data_playlists = pd.read_csv("data_playlists.csv")

# %%
dict_tracks = {"playlist_id":[], "track_id":[], "popularity":[], "track_url":[]} 
dict_verif = {"verif":[]}
def get_tracks(access_token, data_playlists, dict_tracks):
    dict_tracks = {"playlist_id":[], "track_id":[], "popularity":[], "track_url":[]} 
    headers = {
      "Authorization": f"Bearer {access_token}"}
    for i in data_playlists["id"]:
        time.sleep(0.5)
        endpoint = "https://api.spotify.com/v1/playlists/" + str(i) + "/tracks"
        params = {'market':'FR'}
        r = requests.get(endpoint, headers=headers, params=params) 
        if str(r) == '<Response [401]>' :
                print("access_token")
                return dict_tracks
        else:
            response_dict = json.loads(r.text)
            for j in range(int(response_dict["total"])):
                try:
                    dict_tracks["playlist_id"].append(str(i))
                    try:
                        dict_tracks["track_id"].append(response_dict["items"][j]["track"]["id"])
                    except:
                        dict_tracks["track_id"].append("")
                    try:
                        dict_tracks["popularity"].append(response_dict["items"][j]["track"]["popularity"])
                    except:
                        dict_tracks["popularity"].append("")
                    try:
                        dict_tracks["track_url"].append(response_dict["items"][j]["track"]["external_urls"]["spotify"])
                    except:
                        dict_tracks["track_url"].append("")
                except:
                    break
    return dict_tracks

# %%
access_token = "BQCIwGPKjGEaxss0h-xGKWRjlBN0PfAUpu_rfVT0eB03E2pGD1d9iFv7K1A8B6GUr6IK-kX4Yyi51-3vkTiVRBvJpzRiexDSjeMduvuxj-Q4WsSPrBIaCi551_UXDYT68du_1N5ynZPxMOICHWfXkw0zI2_31u-0ZJ0zp-RVoxWTLbRd"
get_tracks(access_token, data_playlists.iloc[1300:1398,:], dict_tracks)

# %%
def my_function(x):
    return len(list(dict.fromkeys(x)))

# %%
my_function(dict_tracks["playlist_id"])
# Out:
# 278

# %%
data_tracks = pd.DataFrame.from_dict(dict_tracks)

# %%
data_tracks.to_csv("data_tracks2.csv")

# %%
data_playlists.iloc[182:,:]
# Out:
#                                names  \
# 182        Spotify Orchestra: Violin
# 183         Spotify Orchestra: Viola
# 184   Spotify Orchestra: Double Bass
# 185         Spotify Orchestra: Cello
# 186              Classical Halloween
# ...                              ...
# 1393                    Women of Pop
# 1394                            dw-c
# 1395                            dw_g
# 1396                Top Shower Songs
# 1397         foodora dinner playlist
#
#                                             description  \
# 182   100 renowned violinists play 100 works, from f...
# 183   The burnished, golden sound of the viola could...
# 184   The double bass has the deepest voice among st...
# 185   Cello is the closest sounding instrument to th...
# 186   A spine-chilling selection of classical favour...
# ...                                                 ...
# 1393                  Kick back with the queens of pop.
# 1394
# 1395
# 1396
# 1397
#
# ...

# %%
data_tracks.head()
# Out:
#               playlist_id                track_id popularity  \
# 0  37i9dQZF1DWXmxXDRgAKVq  13v5IXnvO2BccWwOx5rb4s         64
# 1  37i9dQZF1DWXmxXDRgAKVq  2N8jIpNMutjwnt50OroVVL         69
# 2  37i9dQZF1DWXmxXDRgAKVq  643PW82aBMUa1FiWi5VQY7         72
# 3  37i9dQZF1DWXmxXDRgAKVq  2hyF1YWdX8yxExvRelT9nB         63
# 4  37i9dQZF1DWXmxXDRgAKVq  3eYXE4SPxwKUVQhRmJS5fD         48
#
#                                            track_url
# 0  https://open.spotify.com/track/13v5IXnvO2BccWw...
# 1  https://open.spotify.com/track/2N8jIpNMutjwnt5...
# 2  https://open.spotify.com/track/643PW82aBMUa1Fi...
# 3  https://open.spotify.com/track/2hyF1YWdX8yxExv...
# 4  https://open.spotify.com/track/3eYXE4SPxwKUVQh...

# %%
dict_verif = {"verif":[]}
def analyse_tracks(access_token, data_tracks):
    try:
        df_analyse = pd.read_csv("data_analyse.csv")
        pos = len(pd.read_csv("data_analyse.csv"))
    except:
        df_analyse = pd.DataFrame()
        pos = 0
    headers = {
      "Authorization": f"Bearer {access_token}"}
    nb_track = 0
    data_tracks = data_tracks.iloc[pos :, :]
    for i in data_tracks["track_id"]:
        if nb_track == 200:
            time.sleep(5)
            nb_track = 0
        time.sleep(0.5)
        dict_verif["verif"].append(i)
        endpoint = "https://api.spotify.com/v1/audio-features/" + str(i) 
        try:
            r = requests.get(endpoint, headers=headers) 
        except ConnectionError:
            time.sleep(10)
            r = requests.get(endpoint, headers=headers) 
        nb_track += 1
        if str(r) == '<Response [401]>' :
                print("access_token")
                return df_analyse
        else:
            try:
                response_dict = json.loads(r.text)
                df_analyse = df_analyse.append(response_dict, ignore_index=True)
                df_analyse.to_csv("data_analyse.csv")
            except:
                pass
        
    return df_analyse

# %%
#test = pd.read_csv("data_analyse.csv")
#test.iloc[:2284,:].to_csv("data_analyse.csv")

# %%
track1 = pd.read_csv("data_tracks.csv")
track2 = pd.read_csv("data_tracks2.csv")
data_tracks_final = pd.concat([track1, track2])

# %%
data_tracks_final.reset_index().iloc[:,2:]
# Out:
#                    playlist_id                track_id  popularity  \
# 0       37i9dQZF1DXcBWIGoYBM5M  4MmMxyew8yq1OEyJOMaX6M         0.0
# 1       37i9dQZF1DXcBWIGoYBM5M  5QO79kh1waicV47BqGRL3g        97.0
# 2       37i9dQZF1DXcBWIGoYBM5M  3Ofmpyhv5UAQ70mENzB277        95.0
# 3       37i9dQZF1DXcBWIGoYBM5M  1diS6nkxMQc3wwC4G1j0bh        89.0
# 4       37i9dQZF1DXcBWIGoYBM5M  7MAibcTli4IisCtbHKrGMh        92.0
# ...                        ...                     ...         ...
# 104422  4lgseztVwmKQ8MNETPVIny  0VQjTLPG8l3egUHmIxe265        55.0
# 104423  4lgseztVwmKQ8MNETPVIny  3FCto7hnn1shUyZL42YgfO        67.0
# 104424  4lgseztVwmKQ8MNETPVIny  3XVBdLihbNbxUwZosxcGuJ        79.0
# 104425  4lgseztVwmKQ8MNETPVIny  3bNv3VuUOKgrf5hu3YcuRo        80.0
# 104426  4lgseztVwmKQ8MNETPVIny  1VdZ0vKfR5jneCmWIUAMxK        77.0
#
#                                                 track_url
# 0       https://open.spotify.com/track/4MmMxyew8yq1OEy...
# ...

# %%
data_tracks_final.to_csv("data_tracks_final.csv")

# %%
data_final = pd.read_csv("data_tracks_final.csv")

# %%
data_final = data_final.dropna()
#data_final = data_final.iloc[:,2:]
data_final.to_csv("data_tracks_final.csv", index = False)
data_final_dupli = data_final.drop_duplicates(subset='track_id', keep="first").reset_index(drop=True)
data_final_dupli
# Out:
#                   playlist_id                track_id  popularity  \
# 0      37i9dQZF1DXcBWIGoYBM5M  4MmMxyew8yq1OEyJOMaX6M         0.0
# 1      37i9dQZF1DXcBWIGoYBM5M  5QO79kh1waicV47BqGRL3g        97.0
# 2      37i9dQZF1DXcBWIGoYBM5M  3Ofmpyhv5UAQ70mENzB277        95.0
# 3      37i9dQZF1DXcBWIGoYBM5M  1diS6nkxMQc3wwC4G1j0bh        89.0
# 4      37i9dQZF1DXcBWIGoYBM5M  7MAibcTli4IisCtbHKrGMh        92.0
# ...                       ...                     ...         ...
# 66525  0RTz1jFo5BXGPfI8eVf8sj  5MEYDJVJMaGAXfddTo0D6J        59.0
# 66526  0RTz1jFo5BXGPfI8eVf8sj  4jUuqKRr1fB4c1RvU6syls        53.0
# 66527  0RTz1jFo5BXGPfI8eVf8sj  26NX1wPt1TRCH536yocd6i        68.0
# 66528  0RTz1jFo5BXGPfI8eVf8sj  7tefUew2RUuSAqHyegMoY1        61.0
# 66529  0RTz1jFo5BXGPfI8eVf8sj  3kSXn1osC89W8JcPLozTzs        67.0
#
#                                                track_url
# 0      https://open.spotify.com/track/4MmMxyew8yq1OEy...
# 1      https://open.spotify.com/track/5QO79kh1waicV47...
# ...

# %%
analyse_tracks(access_token, data_final_dupli)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e3146092f586> in <module>
# ----> 1 analyse_tracks(access_token, data_final_dupli)
#
# <ipython-input-9-dc21d56ce9a3> in analyse_tracks(access_token, data_tracks)
#      15             time.sleep(5)
#      16             nb_track = 0
# ---> 17         time.sleep(0.5)
#      18         dict_verif["verif"].append(i)
#      19         endpoint = "https://api.spotify.com/v1/audio-features/" + str(i)
#
# KeyboardInterrupt:

# %%
data_final
# Out:
#                   playlist_id                track_id  popularity  \
# 0      37i9dQZF1DXcBWIGoYBM5M  4MmMxyew8yq1OEyJOMaX6M         0.0
# 1      37i9dQZF1DXcBWIGoYBM5M  5QO79kh1waicV47BqGRL3g        97.0
# 2      37i9dQZF1DXcBWIGoYBM5M  3Ofmpyhv5UAQ70mENzB277        95.0
# 3      37i9dQZF1DXcBWIGoYBM5M  1diS6nkxMQc3wwC4G1j0bh        89.0
# 4      37i9dQZF1DXcBWIGoYBM5M  7MAibcTli4IisCtbHKrGMh        92.0
# ...                       ...                     ...         ...
# 88165  4lgseztVwmKQ8MNETPVIny  0VQjTLPG8l3egUHmIxe265        55.0
# 88166  4lgseztVwmKQ8MNETPVIny  3FCto7hnn1shUyZL42YgfO        67.0
# 88167  4lgseztVwmKQ8MNETPVIny  3XVBdLihbNbxUwZosxcGuJ        79.0
# 88168  4lgseztVwmKQ8MNETPVIny  3bNv3VuUOKgrf5hu3YcuRo        80.0
# 88169  4lgseztVwmKQ8MNETPVIny  1VdZ0vKfR5jneCmWIUAMxK        77.0
#
#                                                track_url
# 0      https://open.spotify.com/track/4MmMxyew8yq1OEy...
# 1      https://open.spotify.com/track/5QO79kh1waicV47...
# ...

# %%
import base64
import datetime
from urllib.parse import urlencode
import requests

# %%
import time

# %%
#définition d'une classe erreur qui envoie un message

# %%
access_token = spoti.get_access_token()

# %%
access_token = "BQBiRCNxzI5cucMubBNd6TQ34HxWLGViRyKP-gJsNcAzaiv1IwAEx69yvrLt38BMGe6KCFXM7aC8OJZit9XoVuKePp-5aA1qvwArvHqALPf0z5GSxbCMMpa7hKVlROWIVE4VtWj9iuCujQTB6-cTX2G1ZwMuVon26tQU06QXwCBgcmaN"

# %%
test = {
  "href": "https://api.spotify.com/v1/playlists/37i9dQZF1DX1lVhptIYRda/tracks?offset=5&limit=10&market=FR",
  "items": [
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/6x2LnllRG5uGarZMsD4iO8"
              },
              "href": "https://api.spotify.com/v1/artists/6x2LnllRG5uGarZMsD4iO8",
              "id": "6x2LnllRG5uGarZMsD4iO8",
              "name": "Thomas Rhett",
              "type": "artist",
              "uri": "spotify:artist:6x2LnllRG5uGarZMsD4iO8"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/54gUAvhpOHFDhHGAINyogO"
          },
          "href": "https://api.spotify.com/v1/albums/54gUAvhpOHFDhHGAINyogO",
          "id": "54gUAvhpOHFDhHGAINyogO",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273d1c4318677a4ec26efabe901",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02d1c4318677a4ec26efabe901",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851d1c4318677a4ec26efabe901",
              "width": 64
            }
          ],
          "name": "Country Again (Side A)",
          "release_date": "2021-03-05",
          "release_date_precision": "day",
          "total_tracks": 3,
          "type": "album",
          "uri": "spotify:album:54gUAvhpOHFDhHGAINyogO"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/6x2LnllRG5uGarZMsD4iO8"
            },
            "href": "https://api.spotify.com/v1/artists/6x2LnllRG5uGarZMsD4iO8",
            "id": "6x2LnllRG5uGarZMsD4iO8",
            "name": "Thomas Rhett",
            "type": "artist",
            "uri": "spotify:artist:6x2LnllRG5uGarZMsD4iO8"
          }
        ],
        "disc_number": 1,
        "duration_ms": 172586,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "USLXJ2107587"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/7KRcMPOGQA0WOw0T8qeXD7"
        },
        "href": "https://api.spotify.com/v1/tracks/7KRcMPOGQA0WOw0T8qeXD7",
        "id": "7KRcMPOGQA0WOw0T8qeXD7",
        "is_local": False,
        "is_playable": True,
        "name": "Want It Again",
        "popularity": 72,
        "preview_url": None,
        "track": True,
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:7KRcMPOGQA0WOw0T8qeXD7"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/31n3CN1jSC5ALUJ9dwT8UI"
              },
              "href": "https://api.spotify.com/v1/artists/31n3CN1jSC5ALUJ9dwT8UI",
              "id": "31n3CN1jSC5ALUJ9dwT8UI",
              "name": "Kameron Marlowe",
              "type": "artist",
              "uri": "spotify:artist:31n3CN1jSC5ALUJ9dwT8UI"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0IzNkQjU9fUw1SlVgQDckM"
          },
          "href": "https://api.spotify.com/v1/albums/0IzNkQjU9fUw1SlVgQDckM",
          "id": "0IzNkQjU9fUw1SlVgQDckM",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2739373be533b1a88ddc0c969d0",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e029373be533b1a88ddc0c969d0",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d000048519373be533b1a88ddc0c969d0",
              "width": 64
            }
          ],
          "name": "Burn 'Em All",
          "release_date": "2020-06-26",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:0IzNkQjU9fUw1SlVgQDckM"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/31n3CN1jSC5ALUJ9dwT8UI"
            },
            "href": "https://api.spotify.com/v1/artists/31n3CN1jSC5ALUJ9dwT8UI",
            "id": "31n3CN1jSC5ALUJ9dwT8UI",
            "name": "Kameron Marlowe",
            "type": "artist",
            "uri": "spotify:artist:31n3CN1jSC5ALUJ9dwT8UI"
          }
        ],
        "disc_number": 1,
        "duration_ms": 185305,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "USRN12000015"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/2UBvtKeetnXn6lMnsBUrZz"
        },
        "href": "https://api.spotify.com/v1/tracks/2UBvtKeetnXn6lMnsBUrZz",
        "id": "2UBvtKeetnXn6lMnsBUrZz",
        "is_local": False,
        "is_playable": True,
        "name": "Burn 'Em All",
        "popularity": 72,
        "preview_url": "https://p.scdn.co/mp3-preview/1b9337c1ceb8e25a1083c160ed4ef2beef0534f4?cid=774b29d4f13844c495f206cafdad9c86",
        "track": True,
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:2UBvtKeetnXn6lMnsBUrZz"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/78eqps3BavCqe2q7GCU1VK"
              },
              "href": "https://api.spotify.com/v1/artists/78eqps3BavCqe2q7GCU1VK",
              "id": "78eqps3BavCqe2q7GCU1VK",
              "name": "Tyler Rich",
              "type": "artist",
              "uri": "spotify:artist:78eqps3BavCqe2q7GCU1VK"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/37GJGzAddc4qHBq4UySNLS"
          },
          "href": "https://api.spotify.com/v1/albums/37GJGzAddc4qHBq4UySNLS",
          "id": "37GJGzAddc4qHBq4UySNLS",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b27383f1f092d6b0dd046d10ae05",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e0283f1f092d6b0dd046d10ae05",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d0000485183f1f092d6b0dd046d10ae05",
              "width": 64
            }
          ],
          "name": "Better Than You're Used To",
          "release_date": "2021-02-12",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:37GJGzAddc4qHBq4UySNLS"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/78eqps3BavCqe2q7GCU1VK"
            },
            "href": "https://api.spotify.com/v1/artists/78eqps3BavCqe2q7GCU1VK",
            "id": "78eqps3BavCqe2q7GCU1VK",
            "name": "Tyler Rich",
            "type": "artist",
            "uri": "spotify:artist:78eqps3BavCqe2q7GCU1VK"
          }
        ],
        "disc_number": 1,
        "duration_ms": 198034,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "USLXJ2141088"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/7stizS5H8h8ABU390mkhZC"
        },
        "href": "https://api.spotify.com/v1/tracks/7stizS5H8h8ABU390mkhZC",
        "id": "7stizS5H8h8ABU390mkhZC",
        "is_local": False,
        "is_playable": True,
        "name": "Better Than You’re Used To",
        "popularity": 70,
        "preview_url": None,
        "track": True,
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:7stizS5H8h8ABU390mkhZC"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/3bhu7P5PfngueRHiB9hjcx"
              },
              "href": "https://api.spotify.com/v1/artists/3bhu7P5PfngueRHiB9hjcx",
              "id": "3bhu7P5PfngueRHiB9hjcx",
              "name": "Elle King",
              "type": "artist",
              "uri": "spotify:artist:3bhu7P5PfngueRHiB9hjcx"
            },
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/66lH4jAE7pqPlOlzUKbwA0"
              },
              "href": "https://api.spotify.com/v1/artists/66lH4jAE7pqPlOlzUKbwA0",
              "id": "66lH4jAE7pqPlOlzUKbwA0",
              "name": "Miranda Lambert",
              "type": "artist",
              "uri": "spotify:artist:66lH4jAE7pqPlOlzUKbwA0"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/6F6ZYE96lTFgzWotepEDhZ"
          },
          "href": "https://api.spotify.com/v1/albums/6F6ZYE96lTFgzWotepEDhZ",
          "id": "6F6ZYE96lTFgzWotepEDhZ",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273c543eab4c605e09a6c0446e8",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02c543eab4c605e09a6c0446e8",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851c543eab4c605e09a6c0446e8",
              "width": 64
            }
          ],
          "name": "Drunk (And I Don't Wanna Go Home)",
          "release_date": "2021-02-26",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:6F6ZYE96lTFgzWotepEDhZ"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/3bhu7P5PfngueRHiB9hjcx"
            },
            "href": "https://api.spotify.com/v1/artists/3bhu7P5PfngueRHiB9hjcx",
            "id": "3bhu7P5PfngueRHiB9hjcx",
            "name": "Elle King",
            "type": "artist",
            "uri": "spotify:artist:3bhu7P5PfngueRHiB9hjcx"
          },
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/66lH4jAE7pqPlOlzUKbwA0"
            },
            "href": "https://api.spotify.com/v1/artists/66lH4jAE7pqPlOlzUKbwA0",
            "id": "66lH4jAE7pqPlOlzUKbwA0",
            "name": "Miranda Lambert",
            "type": "artist",
            "uri": "spotify:artist:66lH4jAE7pqPlOlzUKbwA0"
          }
        ],
        "disc_number": 1,
        "duration_ms": 245625,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "USRC12100003"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/0QULNNd9z5s35entfiiXoa"
        },
        "href": "https://api.spotify.com/v1/tracks/0QULNNd9z5s35entfiiXoa",
        "id": "0QULNNd9z5s35entfiiXoa",
        "is_local": False,
        "is_playable": True,
        "name": "Drunk (And I Don't Wanna Go Home)",
        "popularity": 74,
        "preview_url": "https://p.scdn.co/mp3-preview/ef07063345185993355d2c19c0cba7aac6bca8ea?cid=774b29d4f13844c495f206cafdad9c86",
        "track": True,
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:0QULNNd9z5s35entfiiXoa"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/0FvJm0y2eHw0aPkLLU3sIG"
              },
              "href": "https://api.spotify.com/v1/artists/0FvJm0y2eHw0aPkLLU3sIG",
              "id": "0FvJm0y2eHw0aPkLLU3sIG",
              "name": "Filmore",
              "type": "artist",
              "uri": "spotify:artist:0FvJm0y2eHw0aPkLLU3sIG"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0rpP7RK9FEdwTC8BDjDSLj"
          },
          "href": "https://api.spotify.com/v1/albums/0rpP7RK9FEdwTC8BDjDSLj",
          "id": "0rpP7RK9FEdwTC8BDjDSLj",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b27311a740aec842ebd4d4aa7adc",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e0211a740aec842ebd4d4aa7adc",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d0000485111a740aec842ebd4d4aa7adc",
              "width": 64
            }
          ],
          "name": "State I'm In",
          "release_date": "2020-09-25",
          "release_date_precision": "day",
          "total_tracks": 18,
          "type": "album",
          "uri": "spotify:album:0rpP7RK9FEdwTC8BDjDSLj"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/0FvJm0y2eHw0aPkLLU3sIG"
            },
            "href": "https://api.spotify.com/v1/artists/0FvJm0y2eHw0aPkLLU3sIG",
            "id": "0FvJm0y2eHw0aPkLLU3sIG",
            "name": "Filmore",
            "type": "artist",
            "uri": "spotify:artist:0FvJm0y2eHw0aPkLLU3sIG"
          }
        ],
        "disc_number": 1,
        "duration_ms": 193144,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "USCRB2000101"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/1LtiNpTzzSX8qcvlPFLmeR"
        },
        "href": "https://api.spotify.com/v1/tracks/1LtiNpTzzSX8qcvlPFLmeR",
        "id": "1LtiNpTzzSX8qcvlPFLmeR",
        "is_local": False,
        "is_playable": True,
        "name": "Nothing's Better",
        "popularity": 70,
        "preview_url": "https://p.scdn.co/mp3-preview/73192830b7cd72253b0751a1b772309020388307?cid=774b29d4f13844c495f206cafdad9c86",
        "track": True,
        "track_number": 8,
        "type": "track",
        "uri": "spotify:track:1LtiNpTzzSX8qcvlPFLmeR"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn"
              },
              "href": "https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn",
              "id": "6pBNfggcZZDCmb0p92OnGn",
              "name": "Chase Rice",
              "type": "artist",
              "uri": "spotify:artist:6pBNfggcZZDCmb0p92OnGn"
            },
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/3b8QkneNDz4JHKKKlLgYZg"
              },
              "href": "https://api.spotify.com/v1/artists/3b8QkneNDz4JHKKKlLgYZg",
              "id": "3b8QkneNDz4JHKKKlLgYZg",
              "name": "Florida Georgia Line",
              "type": "artist",
              "uri": "spotify:artist:3b8QkneNDz4JHKKKlLgYZg"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/5H6lxubLtZamdoXEmVmcbz"
          },
          "href": "https://api.spotify.com/v1/albums/5H6lxubLtZamdoXEmVmcbz",
          "id": "5H6lxubLtZamdoXEmVmcbz",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2736576a2a89b81c3c052faaf45",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e026576a2a89b81c3c052faaf45",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d000048516576a2a89b81c3c052faaf45",
              "width": 64
            }
          ],
          "name": "Drinkin' Beer. Talkin' God. Amen. (feat. Florida Georgia Line)",
          "release_date": "2020-11-30",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:5H6lxubLtZamdoXEmVmcbz"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn"
            },
            "href": "https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn",
            "id": "6pBNfggcZZDCmb0p92OnGn",
            "name": "Chase Rice",
            "type": "artist",
            "uri": "spotify:artist:6pBNfggcZZDCmb0p92OnGn"
          },
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/3b8QkneNDz4JHKKKlLgYZg"
            },
            "href": "https://api.spotify.com/v1/artists/3b8QkneNDz4JHKKKlLgYZg",
            "id": "3b8QkneNDz4JHKKKlLgYZg",
            "name": "Florida Georgia Line",
            "type": "artist",
            "uri": "spotify:artist:3b8QkneNDz4JHKKKlLgYZg"
          }
        ],
        "disc_number": 1,
        "duration_ms": 160839,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "QMRSZ2002606"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/1UYfAU2bwgjaM5rIIPQleC"
        },
        "href": "https://api.spotify.com/v1/tracks/1UYfAU2bwgjaM5rIIPQleC",
        "id": "1UYfAU2bwgjaM5rIIPQleC",
        "is_local": False,
        "is_playable": True,
        "name": "Drinkin' Beer. Talkin' God. Amen. (feat. Florida Georgia Line)",
        "popularity": 73,
        "preview_url": "https://p.scdn.co/mp3-preview/536797aa9091fb5d9c3c5129203a4b6f05e920e3?cid=774b29d4f13844c495f206cafdad9c86",
        "track": True,
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:1UYfAU2bwgjaM5rIIPQleC"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/3grHWM9bx2E9vwJCdlRv9O"
              },
              "href": "https://api.spotify.com/v1/artists/3grHWM9bx2E9vwJCdlRv9O",
              "id": "3grHWM9bx2E9vwJCdlRv9O",
              "name": "Kenny Chesney",
              "type": "artist",
              "uri": "spotify:artist:3grHWM9bx2E9vwJCdlRv9O"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/0t7ccDIa3CbqzFrL9rOpaw"
          },
          "href": "https://api.spotify.com/v1/albums/0t7ccDIa3CbqzFrL9rOpaw",
          "id": "0t7ccDIa3CbqzFrL9rOpaw",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273bbe08f107e81819abf0445a1",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02bbe08f107e81819abf0445a1",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851bbe08f107e81819abf0445a1",
              "width": 64
            }
          ],
          "name": "Here And Now",
          "release_date": "2020-05-01",
          "release_date_precision": "day",
          "total_tracks": 12,
          "type": "album",
          "uri": "spotify:album:0t7ccDIa3CbqzFrL9rOpaw"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/3grHWM9bx2E9vwJCdlRv9O"
            },
            "href": "https://api.spotify.com/v1/artists/3grHWM9bx2E9vwJCdlRv9O",
            "id": "3grHWM9bx2E9vwJCdlRv9O",
            "name": "Kenny Chesney",
            "type": "artist",
            "uri": "spotify:artist:3grHWM9bx2E9vwJCdlRv9O"
          }
        ],
        "disc_number": 1,
        "duration_ms": 226266,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "USWB12000429"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/2EEfUuBRZA4Ax1vYcluFS0"
        },
        "href": "https://api.spotify.com/v1/tracks/2EEfUuBRZA4Ax1vYcluFS0",
        "id": "2EEfUuBRZA4Ax1vYcluFS0",
        "is_local": False,
        "is_playable": True,
        "name": "Knowing You",
        "popularity": 61,
        "preview_url": "https://p.scdn.co/mp3-preview/770c52b8a349c89c8c6258912a9415f0284f3d84?cid=774b29d4f13844c495f206cafdad9c86",
        "track": True,
        "track_number": 5,
        "type": "track",
        "uri": "spotify:track:2EEfUuBRZA4Ax1vYcluFS0"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "album",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/1dID9zgn0OV0Y8ud7Mh2tS"
              },
              "href": "https://api.spotify.com/v1/artists/1dID9zgn0OV0Y8ud7Mh2tS",
              "id": "1dID9zgn0OV0Y8ud7Mh2tS",
              "name": "Dustin Lynch",
              "type": "artist",
              "uri": "spotify:artist:1dID9zgn0OV0Y8ud7Mh2tS"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/2jGU6wUOYlyscEVAh6dtg5"
          },
          "href": "https://api.spotify.com/v1/albums/2jGU6wUOYlyscEVAh6dtg5",
          "id": "2jGU6wUOYlyscEVAh6dtg5",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b27364d794492dd0ac2e023787a7",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e0264d794492dd0ac2e023787a7",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d0000485164d794492dd0ac2e023787a7",
              "width": 64
            }
          ],
          "name": "Tullahoma",
          "release_date": "2020-01-17",
          "release_date_precision": "day",
          "total_tracks": 11,
          "type": "album",
          "uri": "spotify:album:2jGU6wUOYlyscEVAh6dtg5"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/1dID9zgn0OV0Y8ud7Mh2tS"
            },
            "href": "https://api.spotify.com/v1/artists/1dID9zgn0OV0Y8ud7Mh2tS",
            "id": "1dID9zgn0OV0Y8ud7Mh2tS",
            "name": "Dustin Lynch",
            "type": "artist",
            "uri": "spotify:artist:1dID9zgn0OV0Y8ud7Mh2tS"
          }
        ],
        "disc_number": 1,
        "duration_ms": 220160,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "QMRSZ1900182"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/51FVpJr3WL7vvdfCa7j2jr"
        },
        "href": "https://api.spotify.com/v1/tracks/51FVpJr3WL7vvdfCa7j2jr",
        "id": "51FVpJr3WL7vvdfCa7j2jr",
        "is_local": False,
        "is_playable": True,
        "name": "Momma’s House",
        "popularity": 74,
        "preview_url": "https://p.scdn.co/mp3-preview/191de6c87838fe14bdc4a10f52fc183afa2f7abf?cid=774b29d4f13844c495f206cafdad9c86",
        "track": True,
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:51FVpJr3WL7vvdfCa7j2jr"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/0fiWOxhsBsQQvFDtxUQWo0"
              },
              "href": "https://api.spotify.com/v1/artists/0fiWOxhsBsQQvFDtxUQWo0",
              "id": "0fiWOxhsBsQQvFDtxUQWo0",
              "name": "Brett Young",
              "type": "artist",
              "uri": "spotify:artist:0fiWOxhsBsQQvFDtxUQWo0"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/6YjMnlV7GWmnUs4lN8bym9"
          },
          "href": "https://api.spotify.com/v1/albums/6YjMnlV7GWmnUs4lN8bym9",
          "id": "6YjMnlV7GWmnUs4lN8bym9",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273501bb9c996bb12d609bf1fba",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02501bb9c996bb12d609bf1fba",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851501bb9c996bb12d609bf1fba",
              "width": 64
            }
          ],
          "name": "Lady",
          "release_date": "2020-05-01",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:6YjMnlV7GWmnUs4lN8bym9"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/0fiWOxhsBsQQvFDtxUQWo0"
            },
            "href": "https://api.spotify.com/v1/artists/0fiWOxhsBsQQvFDtxUQWo0",
            "id": "0fiWOxhsBsQQvFDtxUQWo0",
            "name": "Brett Young",
            "type": "artist",
            "uri": "spotify:artist:0fiWOxhsBsQQvFDtxUQWo0"
          }
        ],
        "disc_number": 1,
        "duration_ms": 193416,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "QM3E22006209"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/3ySLzrN7950dpf1ncttONO"
        },
        "href": "https://api.spotify.com/v1/tracks/3ySLzrN7950dpf1ncttONO",
        "id": "3ySLzrN7950dpf1ncttONO",
        "is_local": False,
        "is_playable": True,
        "name": "Lady",
        "popularity": 75,
        "preview_url": None,
        "track": True,
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:3ySLzrN7950dpf1ncttONO"
      },
      "video_thumbnail": {
        "url": None
      }
    },
    {
      "added_at": "2021-03-30T19:46:53Z",
      "added_by": {
        "external_urls": {
          "spotify": "https://open.spotify.com/user/"
        },
        "href": "https://api.spotify.com/v1/users/",
        "id": "",
        "type": "user",
        "uri": "spotify:user:"
      },
      "is_local": False,
      "primary_color": None,
      "track": {
        "album": {
          "album_type": "single",
          "artists": [
            {
              "external_urls": {
                "spotify": "https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk"
              },
              "href": "https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk",
              "id": "5Zq7R5qmi58ByYyBQTlNuk",
              "name": "Lee Brice",
              "type": "artist",
              "uri": "spotify:artist:5Zq7R5qmi58ByYyBQTlNuk"
            }
          ],
          "external_urls": {
            "spotify": "https://open.spotify.com/album/2HDp9JJaUtB2xU02QGlUif"
          },
          "href": "https://api.spotify.com/v1/albums/2HDp9JJaUtB2xU02QGlUif",
          "id": "2HDp9JJaUtB2xU02QGlUif",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b2730fbe95389a60aef9f12676ab",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e020fbe95389a60aef9f12676ab",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d000048510fbe95389a60aef9f12676ab",
              "width": 64
            }
          ],
          "name": "Memory I Don't Mess With",
          "release_date": "2020-10-16",
          "release_date_precision": "day",
          "total_tracks": 1,
          "type": "album",
          "uri": "spotify:album:2HDp9JJaUtB2xU02QGlUif"
        },
        "artists": [
          {
            "external_urls": {
              "spotify": "https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk"
            },
            "href": "https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk",
            "id": "5Zq7R5qmi58ByYyBQTlNuk",
            "name": "Lee Brice",
            "type": "artist",
            "uri": "spotify:artist:5Zq7R5qmi58ByYyBQTlNuk"
          }
        ],
        "disc_number": 1,
        "duration_ms": 180616,
        "episode": False,
        "explicit": False,
        "external_ids": {
          "isrc": "USCRB2000115"
        },
        "external_urls": {
          "spotify": "https://open.spotify.com/track/7BQE1P0NUalHSvFtrxasx9"
        },
        "href": "https://api.spotify.com/v1/tracks/7BQE1P0NUalHSvFtrxasx9",
        "id": "7BQE1P0NUalHSvFtrxasx9",
        "is_local": False,
        "is_playable": True,
        "name": "Memory I Don't Mess With",
        "popularity": 74,
        "preview_url": "https://p.scdn.co/mp3-preview/12a7510a4f8c93f63d92066fc3860c3cf4e1804d?cid=774b29d4f13844c495f206cafdad9c86",
        "track": True,
        "track_number": 1,
        "type": "track",
        "uri": "spotify:track:7BQE1P0NUalHSvFtrxasx9"
      },
      "video_thumbnail": {
        "url": None
      }
    }
  ],
  "limit": 10,
  "next": "https://api.spotify.com/v1/playlists/37i9dQZF1DX1lVhptIYRda/tracks?offset=15&limit=10&market=FR",
  "offset": 5,
  "previous": "https://api.spotify.com/v1/playlists/37i9dQZF1DX1lVhptIYRda/tracks?offset=0&limit=5&market=FR",
  "total": 52
}

# %%
[test["items"][0]["track"]["artists"][i]["name"] for i in range(0, len(test["items"][0]["track"]["artists"]))]
# Out:
# ['Thomas Rhett']

# %%
test["items"][0]["track"]["artists"][0]["name"]
# Out:
# 'Thomas Rhett'

# %%
response_dict["items"][j]["track"]["external_urls"]["spotify"]
